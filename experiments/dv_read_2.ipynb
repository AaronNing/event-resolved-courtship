# %%
import librosa
import librosa.display
import os
import matplotlib.pyplot as plt
import numpy as np
import scipy.signal as signal
import seaborn as sns
import sys
import pandas as pd

sys.path.append("../utils")
from bitcode import *
from utils import *
from AlignedDvSound import *

# %load_ext autoreload
# %autoreload 2

# %%
aedat_dir = r"D:\Fight\rotation\Wei Zhang\projects\courtship song\data\fromZJC"
aedat_fname = 'dvSave-2021_12_29_16_10_58.aedat4'
dv_path = os.path.join(aedat_dir, aedat_fname)

# %%
# choose wing roi
with AedatFile(dv_path) as f:
    # for frame in f['frames']:
    img = next(f['frames']).image
    
wing_roi = cv2.selectROI(img)
cv2.destroyAllWindows()
print(wing_roi)
# Out:
# (132, 99, 48, 42)

# %%
wing_roi = (132, 99, 48, 42)

# %%
dv = getDvSlice(dv_path, tw=[110,115], fps=40000, roi=wing_roi)
# Out:
# passing packet [100]
# passing packet [200]
# passing packet [300]
# passing packet [400]
# passing packet [500]
# passing packet [600]
# passing packet [700]
# passing packet [800]
# passing packet [900]
# passing packet [1000]
# passing packet [1100]
# passing packet [1200]
# passing packet [1300]
# passing packet [1400]
# passing packet [1500]
# passing packet [1600]
# passing packet [1700]
# passing packet [1800]
# passing packet [1900]
# passing packet [2000]
# passing packet [2100]
# passing packet [2200]
# passing packet [2300]
# passing packet [2400]
# passing packet [2500]
# passing packet [2600]
# passing packet [2700]
# passing packet [2800]
# passing packet [2900]
# passing packet [3000]
# passing packet [3100]
# passing packet [3200]
# passing packet [3300]
# passing packet [3400]
# passing packet [3500]
# passing packet [3600]
# passing packet [3700]
# passing packet [3800]
# passing packet [3900]
# passing packet [4000]
# passing packet [4100]
# passing packet [4200]
# passing packet [4300]
# passing packet [4400]
# passing packet [4500]
# passing packet [4600]
# passing packet [4700]
# passing packet [4800]
# passing packet [4900]
# passing packet [5000]
# passing packet [5100]
# passing packet [5200]
# passing packet [5300]
# passing packet [5400]
# passing packet [5500]
# passing packet [5600]
# passing packet [5700]
# passing packet [5800]
# passing packet [5900]
# passing packet [6000]
# passing packet [6100]
# passing packet [6200]
# passing packet [6300]
# passing packet [6400]
# passing packet [6500]
# passing packet [6600]
# passing packet [6700]
# passing packet [6800]
# passing packet [6900]
# passing packet [7000]
# passing packet [7100]
# passing packet [7200]
# passing packet [7300]
# passing packet [7400]
# passing packet [7500]
# passing packet [7600]
# passing packet [7700]
# passing packet [7800]
# passing packet [7900]
# passing packet [8000]
# passing packet [8100]
# passing packet [8200]
# passing packet [8300]
# passing packet [8400]
# passing packet [8500]
# passing packet [8600]
# passing packet [8700]
# passing packet [8800]
# passing packet [8900]
# passing packet [9000]
# passing packet [9100]
# passing packet [9200]
# passing packet [9300]
# passing packet [9400]
# passing packet [9500]
# passing packet [9600]
# passing packet [9700]
# passing packet [9800]
# passing packet [9900]
# passing packet [10000]
# passing packet [10100]
# passing packet [10200]
# passing packet [10300]
# passing packet [10400]
# passing packet [10500]
# passing packet [10600]
# passing packet [10700]
# passing packet [10800]
# passing packet [10900]
# passing packet [11000]
# passing packet [11100]
# Finishing bin [40000], time [1.0]s
# passing packet [11200]
# Finishing bin [80000], time [2.0]s
# passing packet [11300]
# Finishing bin [120000], time [3.0]s
# passing packet [11400]
# Finishing bin [160000], time [4.0]s
# passing packet [11500]
# Finishing bin [200000], time [5.0]s

# %%
show_spec(dv['x'], sr=dv['sr'], n_fft=512, yscale='log', time_range=[0.5, 2.5])
show_spec(dv['x'], sr=dv['sr'], n_fft=1024, yscale='log', time_range=[0.5, 2.5])
show_spec(dv['x'], sr=dv['sr'], n_fft=2048, yscale='log', time_range=[0.5, 2.5])

# %%
fiji = pd.read_csv(r"D:\Fight\rotation\Wei Zhang\projects\courtship song\data\fromZJC\fromFIJI.csv")

# %%
x, sr = fiji.Mean.values, 600

plt.figure(figsize=[20,4], dpi=300)
plt.plot(x, linewidth=0.5)

show_spec(x, sr=sr, n_fft=32, yscale='log', time_range=[0.2, 5])
