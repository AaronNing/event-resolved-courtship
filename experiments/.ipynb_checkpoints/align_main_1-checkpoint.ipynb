# %%
import librosa
import librosa.display
import os
import matplotlib.pyplot as plt
import numpy as np
import scipy.signal as signal
import seaborn as sns
import sys
import pandas as pd

sys.path.append("../utils")
from bitcode import *
from utils import *
from AlignedDvSound import *

# %load_ext autoreload
# %autoreload 2

# %%
out_dir = r"D:\Fight\rotation\Wei Zhang\projects\courtship song\data\out"

aedat_dir = r"D:\Fight\rotation\Wei Zhang\projects\courtship song\data\aedat"
aedat_fname = 'dvSave-2022_04_02_02_55_09.aedat4'
dv_path = os.path.join(aedat_dir, aedat_fname)

wav_dir = r"D:\Fight\rotation\Wei Zhang\projects\courtship song\data\wav"
wav_name = '20220401_1_main.wav'
wv_path = os.path.join(wav_dir, wav_name)

# %%
# choose align roi
with AedatFile(dv_path) as f:
    # for frame in f['frames']:
    img = next(f['frames']).image

align_roi = cv2.selectROI(img)
cv2.destroyAllWindows()

# wing_roi = cv2.selectROI(img)
# cv2.destroyAllWindows()
print(align_roi)
# Out:
# (219, 235, 35, 25)

# %%
aligned = AlignedDvSound(dv_path, wv_path)
# aligned.alignFromCodes(dv_codes=dv_code, wv_codes=wv_code)
aligned.autoAlign(time_window=[10, 30], roi=align_roi)
# Out:
# passing packet [100]
# passing packet [200]
# passing packet [300]
# passing packet [400]
# passing packet [500]
# passing packet [600]
# passing packet [700]
# passing packet [800]
# passing packet [900]
# passing packet [1000]
# passing packet [1100]
# Finishing bin [5000], time [1.0]s
# passing packet [1200]
# Finishing bin [10000], time [2.0]s
# passing packet [1300]
# Finishing bin [15000], time [3.0]s
# passing packet [1400]
# Finishing bin [20000], time [4.0]s
# passing packet [1500]
# Finishing bin [25000], time [5.0]s
# passing packet [1600]
# Finishing bin [30000], time [6.0]s
# passing packet [1700]
# Finishing bin [35000], time [7.0]s
# passing packet [1800]
# Finishing bin [40000], time [8.0]s
# passing packet [1900]
# Finishing bin [45000], time [9.0]s
# passing packet [2000]
# Finishing bin [50000], time [10.0]s
# passing packet [2100]
# Finishing bin [55000], time [11.0]s
# passing packet [2200]
# Finishing bin [60000], time [12.0]s
# passing packet [2300]
# Finishing bin [65000], time [13.0]s
# passing packet [2400]
# Finishing bin [70000], time [14.0]s
# passing packet [2500]
# Finishing bin [75000], time [15.0]s
# passing packet [2600]
# Finishing bin [80000], time [16.0]s
# passing packet [2700]
# Finishing bin [85000], time [17.0]s
# passing packet [2800]
# Finishing bin [90000], time [18.0]s
# passing packet [2900]
# Finishing bin [95000], time [19.0]s
# passing packet [3000]
# Finishing bin [100000], time [20.0]s

# %%
print(aligned.align)
# Out:
# -10.840875

# %%
slice = aligned.getSlice([60,65], coord='dv', roi=(211, 223, 55, 37))
plt.plot(np.arange(slice['dv']['x'].shape[0]) / slice['dv']['sr'], normalize(slice['dv']['x']), linewidth=0.5)
plt.plot(np.arange(slice['wv']['x'].shape[0]) / slice['wv']['sr'], normalize(slice['wv']['x']), linewidth=0.5)
# Out:
# slicing dv...
# passing packet [100]
# passing packet [200]
# passing packet [300]
# passing packet [400]
# passing packet [500]
# passing packet [600]
# passing packet [700]
# passing packet [800]
# passing packet [900]
# passing packet [1000]
# passing packet [1100]
# passing packet [1200]
# passing packet [1300]
# passing packet [1400]
# passing packet [1500]
# passing packet [1600]
# passing packet [1700]
# passing packet [1800]
# passing packet [1900]
# passing packet [2000]
# passing packet [2100]
# passing packet [2200]
# passing packet [2300]
# passing packet [2400]
# passing packet [2500]
# passing packet [2600]
# passing packet [2700]
# passing packet [2800]
# passing packet [2900]
# passing packet [3000]
# passing packet [3100]
# passing packet [3200]
# passing packet [3300]
# passing packet [3400]
# passing packet [3500]
# passing packet [3600]
# passing packet [3700]
# passing packet [3800]
# passing packet [3900]
# passing packet [4000]
# passing packet [4100]
# passing packet [4200]
# passing packet [4300]
# passing packet [4400]
# passing packet [4500]
# passing packet [4600]
# passing packet [4700]
# passing packet [4800]
# passing packet [4900]
# passing packet [5000]
# passing packet [5100]
# passing packet [5200]
# passing packet [5300]
# passing packet [5400]
# passing packet [5500]
# passing packet [5600]
# passing packet [5700]
# passing packet [5800]
# passing packet [5900]
# passing packet [6000]
# passing packet [6100]
# Finishing bin [5000], time [1.0]s
# passing packet [6200]
# Finishing bin [10000], time [2.0]s
# passing packet [6300]
# Finishing bin [15000], time [3.0]s
# passing packet [6400]
# Finishing bin [20000], time [4.0]s
# passing packet [6500]
# Finishing bin [25000], time [5.0]s
#
# slicing wv...
#
# done

# %%
# choose align roi
with AedatFile(dv_path) as f:
    # for frame in f['frames']:
    img = next(f['frames']).image

# align_roi = cv2.selectROI(img)
# cv2.destroyAllWindows()

wing_roi = cv2.selectROI(img)
cv2.destroyAllWindows()

# %%
print(wing_roi)
# Out:
# (70, 12, 136, 118)

# %%
slice = aligned.getSlice([11*60+13, 11*60+15], coord='wv', roi=wing_roi, fps=20000)
# Out:
# slicing dv...
# passing packet [100]
# passing packet [200]
# passing packet [300]
# passing packet [400]
# passing packet [500]
# passing packet [600]
# passing packet [700]
# passing packet [800]
# passing packet [900]
# passing packet [1000]
# passing packet [1100]
# passing packet [1200]
# passing packet [1300]
# passing packet [1400]
# passing packet [1500]
# passing packet [1600]
# passing packet [1700]
# passing packet [1800]
# passing packet [1900]
# passing packet [2000]
# passing packet [2100]
# passing packet [2200]
# passing packet [2300]
# passing packet [2400]
# passing packet [2500]
# passing packet [2600]
# passing packet [2700]
# passing packet [2800]
# passing packet [2900]
# passing packet [3000]
# passing packet [3100]
# passing packet [3200]
# passing packet [3300]
# passing packet [3400]
# passing packet [3500]
# passing packet [3600]
# passing packet [3700]
# passing packet [3800]
# passing packet [3900]
# passing packet [4000]
# passing packet [4100]
# passing packet [4200]
# passing packet [4300]
# passing packet [4400]
# passing packet [4500]
# passing packet [4600]
# passing packet [4700]
# passing packet [4800]
# passing packet [4900]
# passing packet [5000]
# passing packet [5100]
# passing packet [5200]
# passing packet [5300]
# passing packet [5400]
# passing packet [5500]
# passing packet [5600]
# passing packet [5700]
# passing packet [5800]
# passing packet [5900]
# passing packet [6000]
# passing packet [6100]
# passing packet [6200]
# passing packet [6300]
# passing packet [6400]
# passing packet [6500]
# passing packet [6600]
# passing packet [6700]
# passing packet [6800]
# passing packet [6900]
# passing packet [7000]
# passing packet [7100]
# passing packet [7200]
# passing packet [7300]
# passing packet [7400]
# passing packet [7500]
# passing packet [7600]
# passing packet [7700]
# passing packet [7800]
# passing packet [7900]
# passing packet [8000]
# passing packet [8100]
# passing packet [8200]
# passing packet [8300]
# passing packet [8400]
# passing packet [8500]
# passing packet [8600]
# passing packet [8700]
# passing packet [8800]
# passing packet [8900]
# passing packet [9000]
# passing packet [9100]
# passing packet [9200]
# passing packet [9300]
# passing packet [9400]
# passing packet [9500]
# passing packet [9600]
# passing packet [9700]
# passing packet [9800]
# passing packet [9900]
# passing packet [10000]
# passing packet [10100]
# passing packet [10200]
# passing packet [10300]
# passing packet [10400]
# passing packet [10500]
# passing packet [10600]
# passing packet [10700]
# passing packet [10800]
# passing packet [10900]
# passing packet [11000]
# passing packet [11100]
# passing packet [11200]
# passing packet [11300]
# passing packet [11400]
# passing packet [11500]
# passing packet [11600]
# passing packet [11700]
# passing packet [11800]
# passing packet [11900]
# passing packet [12000]
# passing packet [12100]
# passing packet [12200]
# passing packet [12300]
# passing packet [12400]
# passing packet [12500]
# passing packet [12600]
# passing packet [12700]
# passing packet [12800]
# passing packet [12900]
# passing packet [13000]
# passing packet [13100]
# passing packet [13200]
# passing packet [13300]
# passing packet [13400]
# passing packet [13500]
# passing packet [13600]
# passing packet [13700]
# passing packet [13800]
# passing packet [13900]
# passing packet [14000]
# passing packet [14100]
# passing packet [14200]
# passing packet [14300]
# passing packet [14400]
# passing packet [14500]
# passing packet [14600]
# passing packet [14700]
# passing packet [14800]
# passing packet [14900]
# passing packet [15000]
# passing packet [15100]
# passing packet [15200]
# passing packet [15300]
# passing packet [15400]
# passing packet [15500]
# passing packet [15600]
# passing packet [15700]
# passing packet [15800]
# passing packet [15900]
# passing packet [16000]
# passing packet [16100]
# passing packet [16200]
# passing packet [16300]
# passing packet [16400]
# passing packet [16500]
# passing packet [16600]
# passing packet [16700]
# passing packet [16800]
# passing packet [16900]
# passing packet [17000]
# passing packet [17100]
# passing packet [17200]
# passing packet [17300]
# passing packet [17400]
# passing packet [17500]
# passing packet [17600]
# passing packet [17700]
# passing packet [17800]
# passing packet [17900]
# passing packet [18000]
# passing packet [18100]
# passing packet [18200]
# passing packet [18300]
# passing packet [18400]
# passing packet [18500]
# passing packet [18600]
# passing packet [18700]
# passing packet [18800]
# passing packet [18900]
# passing packet [19000]
# passing packet [19100]
# passing packet [19200]
# passing packet [19300]
# passing packet [19400]
# passing packet [19500]
# passing packet [19600]
# passing packet [19700]
# passing packet [19800]
# passing packet [19900]
# passing packet [20000]
# passing packet [20100]
# passing packet [20200]
# passing packet [20300]
# passing packet [20400]
# passing packet [20500]
# passing packet [20600]
# passing packet [20700]
# passing packet [20800]
# passing packet [20900]
# passing packet [21000]
# passing packet [21100]
# passing packet [21200]
# passing packet [21300]
# passing packet [21400]
# passing packet [21500]
# passing packet [21600]
# passing packet [21700]
# passing packet [21800]
# passing packet [21900]
# passing packet [22000]
# passing packet [22100]
# passing packet [22200]
# passing packet [22300]
# passing packet [22400]
# passing packet [22500]
# passing packet [22600]
# passing packet [22700]
# passing packet [22800]
# passing packet [22900]
# passing packet [23000]
# passing packet [23100]
# passing packet [23200]
# passing packet [23300]
# passing packet [23400]
# passing packet [23500]
# passing packet [23600]
# passing packet [23700]
# passing packet [23800]
# passing packet [23900]
# passing packet [24000]
# passing packet [24100]
# passing packet [24200]
# passing packet [24300]
# passing packet [24400]
# passing packet [24500]
# passing packet [24600]
# passing packet [24700]
# passing packet [24800]
# passing packet [24900]
# passing packet [25000]
# passing packet [25100]
# passing packet [25200]
# passing packet [25300]
# passing packet [25400]
# passing packet [25500]
# passing packet [25600]
# passing packet [25700]
# passing packet [25800]
# passing packet [25900]
# passing packet [26000]
# passing packet [26100]
# passing packet [26200]
# passing packet [26300]
# passing packet [26400]
# passing packet [26500]
# passing packet [26600]
# passing packet [26700]
# passing packet [26800]
# passing packet [26900]
# passing packet [27000]
# passing packet [27100]
# passing packet [27200]
# passing packet [27300]
# passing packet [27400]
# passing packet [27500]
# passing packet [27600]
# passing packet [27700]
# passing packet [27800]
# passing packet [27900]
# passing packet [28000]
# passing packet [28100]
# passing packet [28200]
# passing packet [28300]
# passing packet [28400]
# passing packet [28500]
# passing packet [28600]
# passing packet [28700]
# passing packet [28800]
# passing packet [28900]
# passing packet [29000]
# passing packet [29100]
# passing packet [29200]
# passing packet [29300]
# passing packet [29400]
# passing packet [29500]
# passing packet [29600]
# passing packet [29700]
# passing packet [29800]
# passing packet [29900]
# passing packet [30000]
# passing packet [30100]
# passing packet [30200]
# passing packet [30300]
# passing packet [30400]
# passing packet [30500]
# passing packet [30600]
# passing packet [30700]
# passing packet [30800]
# passing packet [30900]
# passing packet [31000]
# passing packet [31100]
# passing packet [31200]
# passing packet [31300]
# passing packet [31400]
# passing packet [31500]
# passing packet [31600]
# passing packet [31700]
# passing packet [31800]
# passing packet [31900]
# passing packet [32000]
# passing packet [32100]
# passing packet [32200]
# passing packet [32300]
# passing packet [32400]
# passing packet [32500]
# passing packet [32600]
# passing packet [32700]
# passing packet [32800]
# passing packet [32900]
# passing packet [33000]
# passing packet [33100]
# passing packet [33200]
# passing packet [33300]
# passing packet [33400]
# passing packet [33500]
# passing packet [33600]
# passing packet [33700]
# passing packet [33800]
# passing packet [33900]
# passing packet [34000]
# passing packet [34100]
# passing packet [34200]
# passing packet [34300]
# passing packet [34400]
# passing packet [34500]
# passing packet [34600]
# passing packet [34700]
# passing packet [34800]
# passing packet [34900]
# passing packet [35000]
# passing packet [35100]
# passing packet [35200]
# passing packet [35300]
# passing packet [35400]
# passing packet [35500]
# passing packet [35600]
# passing packet [35700]
# passing packet [35800]
# passing packet [35900]
# passing packet [36000]
# passing packet [36100]
# passing packet [36200]
# passing packet [36300]
# passing packet [36400]
# passing packet [36500]
# passing packet [36600]
# passing packet [36700]
# passing packet [36800]
# passing packet [36900]
# passing packet [37000]
# passing packet [37100]
# passing packet [37200]
# passing packet [37300]
# passing packet [37400]
# passing packet [37500]
# passing packet [37600]
# passing packet [37700]
# passing packet [37800]
# passing packet [37900]
# passing packet [38000]
# passing packet [38100]
# passing packet [38200]
# passing packet [38300]
# passing packet [38400]
# passing packet [38500]
# passing packet [38600]
# passing packet [38700]
# passing packet [38800]
# passing packet [38900]
# passing packet [39000]
# passing packet [39100]
# passing packet [39200]
# passing packet [39300]
# passing packet [39400]
# passing packet [39500]
# passing packet [39600]
# passing packet [39700]
# passing packet [39800]
# passing packet [39900]
# passing packet [40000]
# passing packet [40100]
# passing packet [40200]
# passing packet [40300]
# passing packet [40400]
# passing packet [40500]
# passing packet [40600]
# passing packet [40700]
# passing packet [40800]
# passing packet [40900]
# passing packet [41000]
# passing packet [41100]
# passing packet [41200]
# passing packet [41300]
# passing packet [41400]
# passing packet [41500]
# passing packet [41600]
# passing packet [41700]
# passing packet [41800]
# passing packet [41900]
# passing packet [42000]
# passing packet [42100]
# passing packet [42200]
# passing packet [42300]
# passing packet [42400]
# passing packet [42500]
# passing packet [42600]
# passing packet [42700]
# passing packet [42800]
# passing packet [42900]
# passing packet [43000]
# passing packet [43100]
# passing packet [43200]
# passing packet [43300]
# passing packet [43400]
# passing packet [43500]
# passing packet [43600]
# passing packet [43700]
# passing packet [43800]
# passing packet [43900]
# passing packet [44000]
# passing packet [44100]
# passing packet [44200]
# passing packet [44300]
# passing packet [44400]
# passing packet [44500]
# passing packet [44600]
# passing packet [44700]
# passing packet [44800]
# passing packet [44900]
# passing packet [45000]
# passing packet [45100]
# passing packet [45200]
# passing packet [45300]
# passing packet [45400]
# passing packet [45500]
# passing packet [45600]
# passing packet [45700]
# passing packet [45800]
# passing packet [45900]
# passing packet [46000]
# passing packet [46100]
# passing packet [46200]
# passing packet [46300]
# passing packet [46400]
# passing packet [46500]
# passing packet [46600]
# passing packet [46700]
# passing packet [46800]
# passing packet [46900]
# passing packet [47000]
# passing packet [47100]
# passing packet [47200]
# passing packet [47300]
# passing packet [47400]
# passing packet [47500]
# passing packet [47600]
# passing packet [47700]
# passing packet [47800]
# passing packet [47900]
# passing packet [48000]
# passing packet [48100]
# passing packet [48200]
# passing packet [48300]
# passing packet [48400]
# passing packet [48500]
# passing packet [48600]
# passing packet [48700]
# passing packet [48800]
# passing packet [48900]
# passing packet [49000]
# passing packet [49100]
# passing packet [49200]
# passing packet [49300]
# passing packet [49400]
# passing packet [49500]
# passing packet [49600]
# passing packet [49700]
# passing packet [49800]
# passing packet [49900]
# passing packet [50000]
# passing packet [50100]
# passing packet [50200]
# passing packet [50300]
# passing packet [50400]
# passing packet [50500]
# passing packet [50600]
# passing packet [50700]
# passing packet [50800]
# passing packet [50900]
# passing packet [51000]
# passing packet [51100]
# passing packet [51200]
# passing packet [51300]
# passing packet [51400]
# passing packet [51500]
# passing packet [51600]
# passing packet [51700]
# passing packet [51800]
# passing packet [51900]
# passing packet [52000]
# passing packet [52100]
# passing packet [52200]
# passing packet [52300]
# passing packet [52400]
# passing packet [52500]
# passing packet [52600]
# passing packet [52700]
# passing packet [52800]
# passing packet [52900]
# passing packet [53000]
# passing packet [53100]
# passing packet [53200]
# passing packet [53300]
# passing packet [53400]
# passing packet [53500]
# passing packet [53600]
# passing packet [53700]
# passing packet [53800]
# passing packet [53900]
# passing packet [54000]
# passing packet [54100]
# passing packet [54200]
# passing packet [54300]
# passing packet [54400]
# passing packet [54500]
# passing packet [54600]
# passing packet [54700]
# passing packet [54800]
# passing packet [54900]
# passing packet [55000]
# passing packet [55100]
# passing packet [55200]
# passing packet [55300]
# passing packet [55400]
# passing packet [55500]
# passing packet [55600]
# passing packet [55700]
# passing packet [55800]
# passing packet [55900]
# passing packet [56000]
# passing packet [56100]
# passing packet [56200]
# passing packet [56300]
# passing packet [56400]
# passing packet [56500]
# passing packet [56600]
# passing packet [56700]
# passing packet [56800]
# passing packet [56900]
# passing packet [57000]
# passing packet [57100]
# passing packet [57200]
# passing packet [57300]
# passing packet [57400]
# passing packet [57500]
# passing packet [57600]
# passing packet [57700]
# passing packet [57800]
# passing packet [57900]
# passing packet [58000]
# passing packet [58100]
# passing packet [58200]
# passing packet [58300]
# passing packet [58400]
# passing packet [58500]
# passing packet [58600]
# passing packet [58700]
# passing packet [58800]
# passing packet [58900]
# passing packet [59000]
# passing packet [59100]
# passing packet [59200]
# passing packet [59300]
# passing packet [59400]
# passing packet [59500]
# passing packet [59600]
# passing packet [59700]
# passing packet [59800]
# passing packet [59900]
# passing packet [60000]
# passing packet [60100]
# passing packet [60200]
# passing packet [60300]
# passing packet [60400]
# passing packet [60500]
# passing packet [60600]
# passing packet [60700]
# passing packet [60800]
# passing packet [60900]
# passing packet [61000]
# passing packet [61100]
# passing packet [61200]
# passing packet [61300]
# passing packet [61400]
# passing packet [61500]
# passing packet [61600]
# passing packet [61700]
# passing packet [61800]
# passing packet [61900]
# passing packet [62000]
# passing packet [62100]
# passing packet [62200]
# passing packet [62300]
# passing packet [62400]
# passing packet [62500]
# passing packet [62600]
# passing packet [62700]
# passing packet [62800]
# passing packet [62900]
# passing packet [63000]
# passing packet [63100]
# passing packet [63200]
# passing packet [63300]
# passing packet [63400]
# passing packet [63500]
# passing packet [63600]
# passing packet [63700]
# passing packet [63800]
# passing packet [63900]
# passing packet [64000]
# passing packet [64100]
# passing packet [64200]
# passing packet [64300]
# passing packet [64400]
# passing packet [64500]
# passing packet [64600]
# passing packet [64700]
# passing packet [64800]
# passing packet [64900]
# passing packet [65000]
# passing packet [65100]
# passing packet [65200]
# passing packet [65300]
# passing packet [65400]
# passing packet [65500]
# passing packet [65600]
# passing packet [65700]
# passing packet [65800]
# passing packet [65900]
# passing packet [66000]
# passing packet [66100]
# passing packet [66200]
# passing packet [66300]
# Finishing bin [20000], time [1.0]s
# passing packet [66400]
# Finishing bin [40000], time [2.0]s
#
# slicing wv...
#
# done

# %%
import scipy

plt.figure(figsize=[20,5], dpi=300)

b, a = scipy.signal.butter(3, Wn=2*2000/slice['wv']['sr'], btype='highpass', analog=False, output='ba')
x = scipy.signal.filtfilt(b, a, slice['wv']['x'])
plt.plot(np.arange(x.shape[0]) / slice['wv']['sr'], normalize(x), linewidth=0.5)

b, a = scipy.signal.butter(3, Wn=2*2000/slice['dv']['sr'], btype='highpass', analog=False, output='ba')
x = scipy.signal.filtfilt(b, a, slice['dv']['x'])
plt.plot(np.arange(x.shape[0]) / slice['dv']['sr'], normalize(x) + 20, linewidth=0.5)

# %%
slice['wv']['sr']
# Out:
# 48000

# %%
show_spec(slice['wv']['x'], slice['wv']['sr'])
