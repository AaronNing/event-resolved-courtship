# %%
import librosa
import librosa.display
import os
import matplotlib.pyplot as plt
import numpy as np
import scipy.signal as signal
import seaborn as sns
import sys
import pandas as pd

sys.path.append("../utils")
from bitcode import *
from utils import *
from AlignedDvSound import *

# %load_ext autoreload
# %autoreload 2

# %%
out_dir = r"D:\Fight\rotation\Wei Zhang\projects\courtship song\data\out"

aedat_dir = r"D:\Fight\rotation\Wei Zhang\projects\courtship song\data\aedat"
aedat_fname = 'dvSave-2022_04_02_02_51_00_bitcode_test.aedat4'
dv_path = os.path.join(aedat_dir, aedat_fname)

wav_dir = r"D:\Fight\rotation\Wei Zhang\projects\courtship song\data\wav"
wav_name = '20220401_0_bitcode_test.wav'
wv_path = os.path.join(wav_dir, wav_name)

dv_code_path = os.path.join(out_dir, "dvSave-2022_04_02_02_51_00_bitcode_test_codes.csv")
wv_code_path = os.path.join(out_dir, "20220401_0_bitcode_test_codes.csv")

dv_code = pd.read_csv(dv_code_path, index_col=0)
wv_code = pd.read_csv(wv_code_path, index_col=0)

# %%
alignment = getAlignment(dv_code, wv_code, tol=0.1)
sns.histplot(alignment['error'], bins=20)
# Out:
# <AxesSubplot:xlabel='error', ylabel='Count'>

# %%
aligned = AlignedDvSound(dv_path, wv_path)
# aligned.alignFromCodes(dv_codes=dv_code, wv_codes=wv_code)
aligned.autoAlign(time_window=[0, 30], roi=(211, 223, 55, 37))
# Out:
# passing packet [100]
# Finishing bin [5000], time [1.0]s
# passing packet [200]
# Finishing bin [10000], time [2.0]s
# passing packet [300]
# Finishing bin [15000], time [3.0]s
# passing packet [400]
# Finishing bin [20000], time [4.0]s
# passing packet [500]
# Finishing bin [25000], time [5.0]s
# passing packet [600]
# Finishing bin [30000], time [6.0]s
# passing packet [700]
# Finishing bin [35000], time [7.0]s
# passing packet [800]
# Finishing bin [40000], time [8.0]s
# passing packet [900]
# Finishing bin [45000], time [9.0]s
# passing packet [1000]
# Finishing bin [50000], time [10.0]s
# passing packet [1100]
# Finishing bin [55000], time [11.0]s
# passing packet [1200]
# Finishing bin [60000], time [12.0]s
# passing packet [1300]
# Finishing bin [65000], time [13.0]s
# passing packet [1400]
# Finishing bin [70000], time [14.0]s
# passing packet [1500]
# Finishing bin [75000], time [15.0]s
# passing packet [1600]
# Finishing bin [80000], time [16.0]s
# passing packet [1700]
# Finishing bin [85000], time [17.0]s
# passing packet [1800]
# Finishing bin [90000], time [18.0]s
# passing packet [1900]
# Finishing bin [95000], time [19.0]s
# passing packet [2000]
# Finishing bin [100000], time [20.0]s
# passing packet [2100]
# Finishing bin [105000], time [21.0]s
# passing packet [2200]
# Finishing bin [110000], time [22.0]s
# passing packet [2300]
# Finishing bin [115000], time [23.0]s
# passing packet [2400]
# Finishing bin [120000], time [24.0]s
# passing packet [2500]
# Finishing bin [125000], time [25.0]s
# passing packet [2600]
# Finishing bin [130000], time [26.0]s
# passing packet [2700]
# Finishing bin [135000], time [27.0]s
# passing packet [2800]
# Finishing bin [140000], time [28.0]s
# passing packet [2900]
# Finishing bin [145000], time [29.0]s
# passing packet [3000]
# Finishing bin [150000], time [30.0]s

# %%
slice = aligned.getSlice([60,65], coord='dv', roi=(211, 223, 55, 37))
plt.plot(np.arange(slice['dv']['x'].shape[0]) / slice['dv']['sr'], normalize(slice['dv']['x']), linewidth=0.5)
plt.plot(np.arange(slice['wv']['x'].shape[0]) / slice['wv']['sr'], normalize(slice['wv']['x']), linewidth=0.5)
# Out:
# slicing dv...
# passing packet [100]
# passing packet [200]
# passing packet [300]
# passing packet [400]
# passing packet [500]
# passing packet [600]
# passing packet [700]
# passing packet [800]
# passing packet [900]
# passing packet [1000]
# passing packet [1100]
# passing packet [1200]
# passing packet [1300]
# passing packet [1400]
# passing packet [1500]
# passing packet [1600]
# passing packet [1700]
# passing packet [1800]
# passing packet [1900]
# passing packet [2000]
# passing packet [2100]
# passing packet [2200]
# passing packet [2300]
# passing packet [2400]
# passing packet [2500]
# passing packet [2600]
# passing packet [2700]
# passing packet [2800]
# passing packet [2900]
# passing packet [3000]
# passing packet [3100]
# passing packet [3200]
# passing packet [3300]
# passing packet [3400]
# passing packet [3500]
# passing packet [3600]
# passing packet [3700]
# passing packet [3800]
# passing packet [3900]
# passing packet [4000]
# passing packet [4100]
# passing packet [4200]
# passing packet [4300]
# passing packet [4400]
# passing packet [4500]
# passing packet [4600]
# passing packet [4700]
# passing packet [4800]
# passing packet [4900]
# passing packet [5000]
# passing packet [5100]
# passing packet [5200]
# passing packet [5300]
# passing packet [5400]
# passing packet [5500]
# passing packet [5600]
# passing packet [5700]
# passing packet [5800]
# passing packet [5900]
# passing packet [6000]
# passing packet [6100]
# Finishing bin [5000], time [1.0]s
# passing packet [6200]
# Finishing bin [10000], time [2.0]s
# passing packet [6300]
# Finishing bin [15000], time [3.0]s
# passing packet [6400]
# Finishing bin [20000], time [4.0]s
# passing packet [6500]
# Finishing bin [25000], time [5.0]s
#
# slicing wv...
#
# done

# %%
slice = aligned.getSlice([0,5], coord='dv', roi=(211, 223, 55, 37))
plt.plot(np.arange(slice['dv']['x'].shape[0]) / slice['dv']['sr'], normalize(slice['dv']['x']), linewidth=0.5)
plt.plot(np.arange(slice['wv']['x'].shape[0]) / slice['wv']['sr'], normalize(slice['wv']['x']), linewidth=0.5)
# Out:
# slicing dv...
# passing packet [100]
# Finishing bin [5000], time [1.0]s
# passing packet [200]
# Finishing bin [10000], time [2.0]s
# passing packet [300]
# Finishing bin [15000], time [3.0]s
# passing packet [400]
# Finishing bin [20000], time [4.0]s
# passing packet [500]
# Finishing bin [25000], time [5.0]s
#
# slicing wv...
#
# done

# %%
slice = aligned.getSlice([60.5,61.5], coord='wv', roi=(211, 223, 55, 37))
plt.plot(np.arange(slice['dv']['x'].shape[0]) / slice['dv']['sr'], normalize(slice['dv']['x']), linewidth=0.5)
plt.plot(np.arange(slice['wv']['x'].shape[0]) / slice['wv']['sr'], normalize(slice['wv']['x']), linewidth=0.5)
# Out:
# slicing dv...
# passing packet [100]
# passing packet [200]
# passing packet [300]
# passing packet [400]
# passing packet [500]
# passing packet [600]
# passing packet [700]
# passing packet [800]
# passing packet [900]
# passing packet [1000]
# passing packet [1100]
# passing packet [1200]
# passing packet [1300]
# passing packet [1400]
# passing packet [1500]
# passing packet [1600]
# passing packet [1700]
# passing packet [1800]
# passing packet [1900]
# passing packet [2000]
# passing packet [2100]
# passing packet [2200]
# passing packet [2300]
# passing packet [2400]
# passing packet [2500]
# passing packet [2600]
# passing packet [2700]
# passing packet [2800]
# passing packet [2900]
# passing packet [3000]
# passing packet [3100]
# passing packet [3200]
# passing packet [3300]
# passing packet [3400]
# passing packet [3500]
# passing packet [3600]
# passing packet [3700]
# passing packet [3800]
# passing packet [3900]
# passing packet [4000]
# passing packet [4100]
# passing packet [4200]
# passing packet [4300]
# passing packet [4400]
# Finishing bin [5000], time [1.0]s
#
# slicing wv...
#
# done

# %%
slice = aligned.getSlice([60.5,61.5], coord='wv', roi=(211, 223, 55, 37))
plt.plot(np.arange(slice['dv']['x'].shape[0]) / slice['dv']['sr'], normalize(slice['dv']['x']), linewidth=0.5)
plt.plot(np.arange(slice['wv']['x'].shape[0]) / slice['wv']['sr'], normalize(slice['wv']['x']), linewidth=0.5)
